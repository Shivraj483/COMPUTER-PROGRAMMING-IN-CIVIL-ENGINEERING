# %%
#ToCalculatethe lengthoftransittio.curve
V = int(input("Enter the value of design speed:"))
R = int(input("Enter the value of Radius of curvature:"))
N = int(input("Enter the value of slope:"))
W = float(input("Enter the value of width of road including extra widening:"))
emax = float(input("Enter the value for plain terrain:"))

ecal = (V*V / (225*R))
print("The value of Superelevation:", ecal)

if ecal < emax:
    print(ecal)
else:
    print(emax)

Ls = (emax * N * W / 2)
print("The length of transition curve:", Ls)
# Out:
#   File "/tmp/ipython-input-3097697765.py", line 3
#     R=int(input("Enterthevalue ofRadiusofcurvature:"")
#                                                     ^
# SyntaxError: unterminated string literal (detected at line 3)
